# %%
#list all tables in mzdb
import sqlite3
import pandas as pd

# Connect to the mzDB file
conn = sqlite3.connect("demo_data/180205_Poo_TruePoo_Full1.mzDB")

# List all tables
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print("Tables in mzDB file:")
print(tables)

# Close the connection if needed
conn.close()
# Out:
# Tables in mzDB file:
#                              name
# 0                 data_processing
# 1                 sqlite_sequence
# 2                   scan_settings
# 3                   data_encoding
# 4                        software
# 5               processing_method
# 6                          sample
# 7                     source_file
# 8   source_file_scan_settings_map
# 9                              cv
# 10              param_tree_schema
# 11        table_param_tree_schema
# 12              shared_param_tree
# 13       instrument_configuration
# 14                           mzdb
# 15                            run
# 16                   chromatogram
# 17                      run_slice
# 18                   bounding_box
# 19                        cv_term
# 20                        cv_unit
# 21                      user_term
# 22                         target
# 23             bounding_box_rtree
# 24        bounding_box_rtree_node
# 25       bounding_box_rtree_rowid
# ...

# %%
#list all columns in bounding_box
import sqlite3
import pandas as pd

# Connect to the mzDB file
conn = sqlite3.connect("demo_data/180205_Poo_TruePoo_Full1.mzDB")

# Step 1: Check the structure of the 'spectrum' table to understand its columns
spectrum_info = pd.read_sql_query("PRAGMA table_info(bounding_box);", conn)
print("\nColumns in 'bounding_box' table:")
print(spectrum_info)

# Close the connection for now
conn.close()
# Out:
# Columns in 'bounding_box' table:
#    cid               name     type  notnull dflt_value  pk
# 0    0                 id  INTEGER        0       None   1
# 1    1               data     BLOB        1       None   0
# 2    2       run_slice_id  INTEGER        1       None   0
# 3    3  first_spectrum_id  INTEGER        1       None   0
# 4    4   last_spectrum_id  INTEGER        1       None   0

# %%
#RETRIEVES UNPACKED DATA
import sqlite3
import struct

conn = sqlite3.connect("demo_data/180205_Poo_TruePoo_Full1.mzDB")

# Fetch the first BLOB entry in `data` column from `bounding_box`
cursor = conn.cursor()
cursor.execute("SELECT data FROM bounding_box LIMIT 1")
blob_data = cursor.fetchone()[0]

conn.close()

# Interpret the blob data as an array of 32-bit floats (if applicable)
float_data = struct.unpack(f'{len(blob_data) // 4}f', blob_data)

# Print the extracted float values
print(float_data)
# Out:
# (1.401298464324817e-45, 0.0, 2.802596928649634e-45, 0.0, 4.203895392974451e-45, 2.802596928649634e-45, -2.0, 3.226790189743042, 17279.25390625, -2.0, 3.226790189743042, 17279.25390625, 5.605193857299268e-45, 4.203895392974451e-45, 1.8807586044111702e-10, 3.2252981662750244, 193666.515625, 1.8807586044111702e-10, 3.2252981662750244, 193666.515625, 1.8807586044111702e-10, 3.2252981662750244, 193666.515625, 7.006492321624085e-45, 1.401298464324817e-44, 3.6893488147419103e+19, 3.219102382659912, 362151.5, 3.6893488147419103e+19, 3.219102382659912, 362151.5, 2.0, 3.2193868160247803, 301228.96875, -0.0, 3.234849691390991, 1576457.0, -0.0, 3.234849691390991, 1576457.0, 5.6085094428385655e-19, 3.238588809967041, 23676674.0, 5.6085094428385655e-19, 3.238588809967041, 23676674.0, 5.6085094428385655e-19, 3.238588809967041, 23676674.0, 1.82449353629746e-19, 3.2502386569976807, 2600893.5, 1.82449353629746e-19, 3.2502386569976807, 2600893.5, 8.407790785948902e-45, 1.401298464324817e-44, 0.0, 3.219
# ...
